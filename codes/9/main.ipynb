# %%
import MDAnalysis as mda
import numpy as np

# %%
u = mda.Universe('./CH3OH.pdb')
u.atoms.positions = u.atoms.positions@np.array([[0,0,-1],[0,1,0],[1,0,0]])

# %%
c = u.select_atoms('type C')
o = u.select_atoms('type O')
hc = u.select_atoms('type H and around 1.1 group c', c=c)
ho = u.select_atoms('type H and around 1.1 group o', o=o)
u.select_atoms('around 1.07 group c', c=c)
# Out:
# <AtomGroup with 0 atoms>

# %%
np.linalg.norm(c.positions-o.positions), np.linalg.norm(hc[:1].positions-c.positions), np.linalg.norm(ho[:1].positions-c.positions)
# Out:
# (1.43, 1.0702944, 1.9701598)

# %%
list(u.select_atoms('cyzone 5 -100 200 group c', c=c))
# Out:
# []

# %%
u.atoms.center_of_charge()
# Out:
# ---------------------------------------------------------------------------
# NoDataError                               Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 u.atoms.center_of_charge()
#
# File E:\anaconda3\Lib\site-packages\MDAnalysis\core\topologyattrs.py:248, in _build_stub.<locals>.stub_method(self, *args, **kwargs)
#     239 def stub_method(self, *args, **kwargs):
#     240     message = (
#     241         "{class_name}.{method_name}() "
#     242         "not available; this requires {attribute_name}"
#    (...)
#     246         attribute_name=attribute_name,
#     247     )
# --> 248     raise NoDataError(message)
#
# NoDataError: AtomGroup.center_of_charge() not available; this requires charges

# %%
u.add_TopologyAttr('charge', [0,1,2,3,4,5])
u.atoms.center_of_charge()
# Out:
# array([0.0584    , 0.77593331, 0.68806667])

# %%
u.add_TopologyAttr('charge', [0,1,2,3,-4,-5])
u.atoms.center_of_charge(), u.atoms.total_charge()
# Out:
# (array([0.0584    , 0.77593331, 0.68806667]), -3.0)

# %%
u.add_TopologyAttr('charge', [0,1,2,3,4,6])
u.atoms.center_of_charge(), u.atoms.total_charge()
# Out:
# (array([0.109375  , 0.79737497, 0.67631251]), 16.0)

# %%
hc.shape_parameter(),hc.asphericity(),u.atoms.moment_of_inertia(),
# Out:
# (-0.24999935152562397,
#  0.25000021615812534,
#  array([[ 2.11990166e+01, -1.76714767e-03, -2.04547707e-03],
#         [-1.76714767e-03,  2.04010098e+01, -9.26679534e-01],
#         [-2.04547707e-03, -9.26679534e-01,  3.87796270e+00]]))

# %%
import MDAnalysis as mda
from MDAnalysis.tests.datafiles import PSF, DCD
u = mda.Universe(PSF, DCD)
len(u.trajectory)
# Out:
# E:\anaconda3\Lib\site-packages\MDAnalysis\coordinates\DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# 98

# %%
u.trajectory.ts, u.trajectory.time
# Out:
# (< Timestep 10 >, 10.999999031120204)

# %%
u.trajectory.next()
u.trajectory.ts, u.trajectory.time
# Out:
# (< Timestep 11 >, 11.999998943040223)

# %%
u = mda.Universe(PSF, DCD)

u.trajectory[4], u.trajectory[:4],
# Out:
# (< Timestep 4 >,
#  <MDAnalysis.coordinates.base.FrameIteratorSliced at 0x213387af140>)

# %%
from MDAnalysis.analysis import rms
protein = u.select_atoms('protein')
rmsd = rms.RMSD(protein, protein).run()
bools = rmsd.results.rmsd.T[-1] < 4
print(bools)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False]

# %%
rmsd.results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 import nglview as nv
#
# ModuleNotFoundError: No module named 'nglview'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 10
#       5     return ts
#       8 up_by_5 = functools.partial(up_by_x, x=5)
# ---> 10 u = mda.Universe(mda.TPR, XTC, transformations=[up_by_5])
#
# AttributeError: module 'MDAnalysis' has no attribute 'TPR'
